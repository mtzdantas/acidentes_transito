# %%
import pandas as pd
# Out:
# c:\Users\mateu\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# c:\Users\mateu\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %% [markdown]
# ### Carregar e inspecionar o dataset

# %%
acidentes = pd.read_csv('./data/accidents_2017_to_2023.csv', sep=';')

# %%
# Mostrando todas as colunas.
pd.set_option('display.max_columns', None)

# Visualizando tabela.
acidentes.head()
# Out:
#   data_inversa dia_semana   horario  uf     br     km       municipio  \
# 0   01/01/2017    domingo  01:45:00  RS  116.0   34,9         VACARIA
# 1   01/01/2017    domingo  01:00:00  PR  376.0    636  TIJUCAS DO SUL
# 2   01/01/2017    domingo  04:40:00  BA  101.0     65      ENTRE RIOS
# 3   01/01/2017    domingo  06:30:00  PA  316.0   72,5       CASTANHAL
# 4   01/01/2017    domingo  09:00:00  GO   20.0  220,5           POSSE
#
#                 causa_acidente                tipo_acidente  \
# 0  Defeito Mecânico no Veículo             Colisão traseira
# 1      Velocidade Incompatível    Saída de leito carroçável
# 2            Condutor Dormindo              Colisão frontal
# 3  Falta de Atenção à Condução              Colisão lateral
# 4               Defeito na Via  Colisão com objeto estático
#
#   classificacao_acidente     fase_dia  sentido_via condicao_metereologica  \
# 0    Com Vítimas Feridas  Plena Noite  Decrescente              Céu Claro
# 1     Com Vítimas Fatais  Plena Noite    Crescente         Garoa/Chuvisco
# 2     Com Vítimas Fatais    Amanhecer  Decrescente                Nublado
# 3     Com Vítimas Fatais    Amanhecer  Decrescente              Céu Claro
# 4    Com Vítimas Feridas    Pleno dia  Decrescente              Céu Claro
#
#   tipo_pista        tracado_via  pessoas  mortos  feridos_leves  \
# 0    Simples               Reta        6       0              4
# 1      Dupla              Curva        2       1              0
# 2    Simples              Curva        5       1              1
# 3    Simples               Reta        4       1              0
# 4    Simples  Desvio Temporário        3       0              2
#
#    feridos_graves  ilesos  ignorados  feridos  veiculos   latitude  longitude  \
# 0               0       2          0        4         2  -2,85E+07  -5,09E+07
# 1               0       1          0        0         2  -2,58E+07  -4,91E+07
# 2               1       2          0        2         2  -1,20E+07  -3,81E+07
# 3               0       3          0        0         3  -1,29E+06  -4,78E+07
# 4               1       0          0        3         1  -1,41E+07  -4,63E+07
#
#   regional delegacia
# 0  SPRF-RS  DEL05-RS
# 1  SPRF-PR  DEL01-PR
# 2  SPRF-BA  DEL01-BA
# 3  SPRF-PA  DEL01-PA
# 4  SPRF-DF  DEL02-DF

# %%
# Conferindo tipos de dados das colunas.
acidentes.dtypes
# Out:
# data_inversa               object
# dia_semana                 object
# horario                    object
# uf                         object
# br                        float64
# km                         object
# municipio                  object
# causa_acidente             object
# tipo_acidente              object
# classificacao_acidente     object
# fase_dia                   object
# sentido_via                object
# condicao_metereologica     object
# tipo_pista                 object
# tracado_via                object
# pessoas                     int64
# mortos                      int64
# feridos_leves               int64
# feridos_graves              int64
# ilesos                      int64
# ignorados                   int64
# feridos                     int64
# veiculos                    int64
# latitude                   object
# longitude                  object
# regional                   object
# delegacia                  object
# dtype: object

# %% [markdown]
# ### Eliminar colunas que não serão utilizadas

# %%
# Excluindo colunas que não serão utilizadas.
acidentes = acidentes.drop(columns=['br', 'km', 'regional', 'delegacia'])

# %% [markdown]
# ### Tratar valores ausentes (NaN)

# %%
# Conferindo valores ausentes.
acidentes.isna().sum()
# Out:
# data_inversa               0
# dia_semana                 0
# horario                    0
# uf                         0
# municipio                  0
# causa_acidente             0
# tipo_acidente             40
# classificacao_acidente     0
# fase_dia                   0
# sentido_via                0
# condicao_metereologica     0
# tipo_pista                 0
# tracado_via                0
# pessoas                    0
# mortos                     0
# feridos_leves              0
# feridos_graves             0
# ilesos                     0
# ignorados                  0
# feridos                    0
# veiculos                   0
# latitude                   0
# longitude                  0
# dtype: int64

# %%
# Substituindo valores ausentes da coluna tipo_acidente por desconhecido.
acidentes['tipo_acidente'] = acidentes['tipo_acidente'].fillna('Desconhecido')

# %%
# Visualizando tabela.
acidentes[acidentes['tipo_acidente'] == 'Desconhecido'].head()
# Out:
#        data_inversa    dia_semana   horario  uf           municipio  \
# 106146   01/12/2018        sábado  16:00:00  MT              MATUPA
# 107490   21/12/2018   sexta-feira  19:30:00  MG      BELO HORIZONTE
# 107623   15/11/2018  quinta-feira  14:00:00  RO  CANDEIAS DO JAMARI
# 135012   13/07/2018   sexta-feira  21:10:00  SC          GUARAMIRIM
# 152323   09/10/2018   terça-feira  18:30:00  MG              MEDINA
#
#                                            causa_acidente tipo_acidente  \
# 106146  Desobediência às normas de trânsito pelo condutor  Desconhecido
# 107490                 Não guardar distância de segurança  Desconhecido
# 107623  Desobediência às normas de trânsito pelo condutor  Desconhecido
# 135012                             Ultrapassagem Indevida  Desconhecido
# 152323  Desobediência às normas de trânsito pelo condutor  Desconhecido
#
#        classificacao_acidente     fase_dia  sentido_via  \
# 106146    Com Vítimas Feridas    Pleno dia    Crescente
# 107490    Com Vítimas Feridas    Anoitecer  Decrescente
# 107623    Com Vítimas Feridas    Pleno dia    Crescente
# 135012     Com Vítimas Fatais  Plena Noite  Decrescente
# 152323    Com Vítimas Feridas  Plena Noite  Decrescente
#
#        condicao_metereologica tipo_pista        tracado_via  pessoas  mortos  \
# 106146              Céu Claro    Simples               Reta        2       0
# 107490                  Chuva    Simples               Reta        7       0
# 107623              Céu Claro    Simples               Reta        2       0
# 135012              Céu Claro    Simples  Desvio Temporário        3       1
# 152323               Ignorado    Simples               Reta        2       0
#
#         feridos_leves  feridos_graves  ilesos  ignorados  feridos  veiculos  \
# 106146              1               0       1          0        1         2
# 107490              0               3       4          0        3         4
# 107623              0               1       1          0        1         2
# 135012              1               1       0          0        2         2
# 152323              0               1       0          1        1         2
#
#          latitude  longitude
# 106146  -1,01E+07  -5,49E+07
# 107490  -1,98E+07  -4,39E+07
# 107623  -8,79E+06  -6,36E+07
# 135012  -2,65E+07  -4,89E+07
# 152323  -1,63E+07  -4,15E+07

# %% [markdown]
# ### Corrigir tipos de dados

# %%
# Transformando a coluna de data para o tipo datetime.
acidentes['data_inversa'] = pd.to_datetime(acidentes['data_inversa'], format='%d/%m/%Y')

# Separando a data em colunas de dia, mês e ano.
acidentes['dia'] = acidentes['data_inversa'].dt.day
acidentes['mês'] = acidentes['data_inversa'].dt.month
acidentes['ano'] = acidentes['data_inversa'].dt.year
acidentes = acidentes.drop(columns=['data_inversa'])

# %% [markdown]
# ### Remover valores duplicados

# %%
# Conferindo se existe linhas duplicadas.
acidentes.duplicated().sum()
# Out:
# 24

# %%
# Removendo linhas duplicadas.
acidentes = acidentes.drop_duplicates()
